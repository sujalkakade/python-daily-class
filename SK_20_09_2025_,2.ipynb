# %% [markdown]
# <a href="https://colab.research.google.com/github/sujalkakade/python-daily-class/blob/main/SK_20_09_2025_%2C2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Compile time / Method Overloading Polymorphism
class BCA_1st_Semester :
    def student(self,a,b=0,c=0,d=0):
        return a+b+c+d

BCA = BCA_1st_Semester()
print(BCA.student(5))
print(BCA.student(10,7,8))
print(BCA.student(-10,4,9,-5))
print(BCA.student(99,0,4,-12))
# Out:
# 5
# 25
# -2
# 91

# %%
class Animal :
    def sound(self):
        print("Animal makes a sound")

class Dog(Animal):
    def sound(self):
        print("Bow Bow Bow Bow")

class Cat(Animal):
    def sound(self):
        print("Meow Meow Meow")

class Tiger(Animal):
    def sound(self):
        print("Roar Roar Roar")

class Cow(Animal):
    def sound(self):
        print("Ambbbbbaaaaaa")


dog = Dog()
cat = Cat()
tiger = Tiger()
cow = Cow()

dog.sound()
cat.sound()
tiger.sound()
cow.sound()
# Out:
# Bow Bow Bow Bow
# Meow Meow Meow
# Roar Roar Roar
# Ambbbbbaaaaaa

# %%
class Book :
  def __init__(self,page):
    self.page = page
  def __add__(self,other):
    return self.page + other.page
Obj1 = Book(200)
obj2 = Book(300)
print("TOtal page is",Obj1 + obj2)
# Out:
# TOtal page is 500

# %%
#Abstraction example
from abc import ABC,abstractmethod
class Vehicle(ABC):
    @abstractmethod
    def sound(self):
         pass
class Car (Vehicle):
  def sound(self):
      print("I'm driving a car")

obj = Car()
obj.sound()
# Out:
# I'm driving a car

# %%
from abc import ABC,abstractmethod
class Game(ABC):

  #Normal function / method
    def Y_City (self):
      print("Mission completed")


  #Abstract Method / function
    @abstractmethod
    def BGMI (self):
       pass


  #Normal function  / Method
    def Ludo_King (self):
        print("I'm win the game")

class Temple_Run (Game):

   #BGMI function implemented by sub class
     def BGMI(self):
         print("I got a royal pass")

    #Normal function
     def Chess(self):
          print("I'm a district player")

Obj = Temple_Run()
Obj.BGMI()
Obj.Ludo_King()
Obj.Chess()
# Out:
# I got a royal pass
# I'm win the game
# I'm a district player

# %%
# Quiz Competition
def ask_question(question, options, answer):
    print("\n"+ question)
    for key, value in options.items():
        print(f"{key}. {value}")

    user_choice = input("Enter your choice (a/b/c/d): ").lower()

    match user_choice:
        case 'a'|'b'|'c'|'d':
            if user_choice == answer:
                print("✅Correct Answer!")
                return 1
            else:
                print("✖️Wrong Answer!")
                return 0

        case _:
            print("✖️Invalid Choice")
            return 0

print("Welcome to Python Quiz Competition")
player_name=input("Enter your name:")
score=0
questions=[
    {"q":"1)Which of the following is a valid variable name?","options":{"a":"1var","b":"var1","c":"var-1","d":"var 1"},"ans":"b"},

    {"q":"2)What is the output of:x=5;x+=3;print(x)","options":{"a":"8","b":"53","c":"5","d":"Error"},"ans":"a"},

    {"q":"3)Which of the following is immutable?","options":{"a":"List","b":"Set","c":"Tuple","d":"Dictionary"},"ans":"c"},

    {"q":"4)Type of 3.14 in Python?","options":{"a":"int","b":"float","c":"complex","d":"double"},"ans":"b"},

    {"q":"5)Which of these is a dictionary?","options":{"a":"[1,2,3]","b":"(1,2,3)","c":"{'a':1}","d":"{1,2,3}"},"ans":"c"},

    {"q":"6)What is outpu of len({1,2,3,4})?","options":{"a":"3","b":"4","c":"Error","d":"0"},"ans":"b"},

    {"q":"7)Output of 5**2?","options":{"a":"10","b":"25","c":"7","d":"52"},"ans":"b"},

    {"q":"8)Which operator is floor division?","options":{"a":"/","b":"//","c":"%","d":"**"},"ans":"b"},

    {"q":"9)Output of:if5>3:\n print('Yes')","options":{"a":"Yes","b":"No","c":"Error","d":"elifse"},"ans":"a"},

    {"q":"10)Which keyword is used for else-if?","options":{"a":"elseif","b":"elif","c":"else if","d":"elifse"},"ans":"b"},

    {"q":"11)Which loop is used when number of iterations is known?","options":{"a":"for","b":"while","c":"do-while","d":"None"},"ans":"a"},

    {"q":"12)How to exit a loop immediately?","options":{"a":"stop","b":"break","c":"exit","d":"return"},"ans":"b"},

    {"q":"13)Keyword to define a function?","options":{"a":"function","b":"def","c":"fun","d":"define"},"ans":"b"},

    {"q":"14)Function that returns nothing?","options":{"a":"return None","b":"void","c":"pass","d":"All of the above"},"ans":"a"},

    {"q":"15)Which method is the constructor in Python class?","options":{"a":"__init__","b":"__start__","c":"__create__","d":"constructor"},"ans":"a"},

    {"q":"16)Which of these is inheritance example?","options":{"a":"class A:\n pass\nclass B(a):\n pass","b":"x=5","c":"def func():pass","d":"if True:pass"},"ans":"a"},

    {"q":"17)Whatis type of true?","options":{"a":"int","b":"bool","c":"str","d":"float"},"ans":"b"},

    {"q":"18)Which collection type allow duplicates?","options":{"a":"set","b":"dict","c":"list","d":"tuple"},"ans":"c"},

    {"q":"19)Which collection type is  unordered?","options":{"a":"list","b":"tuple","c":"set","d":"string"},"ans":"c"},

    {"q":"20)Output of 10%3?","options":{"a":"3","b":"1","c":"0","d":"error"},"ans":"b"},

    {"q":"21)output of if 5>10:\n print('yes')\n?","options":{"a":"yes","b":"No","c":"Error","d":"5>10"},"ans":"b"},

    {"q":"22)out put of : \nfor i in range(3):\n print (i)","options":{"a":"1 2 3","b":"0 1 2","c":"0 1 2 3 4","d":"1 2"} ,"ans":"b"},

    {"q":"23)Encapulationin pythoinc done by?","options":{"a":"multipal from","b":"single form","c":"polymorpism","d":"abstraction"},"ans":"b"},

    {"q":"24)polymorpism means?","options":{"a":"private variable","b":"Inheritance","c":"Inheritance","d":"encapulation"},"ans":"c"},
    {"q":"25)Dynamic typing means?","options":{"a":"Type assigned at runtime","b":"Type assigned at compile-time","c":"Fixed type","d":"Error"},"ans":"a"},

    {"q":"26)Type of None?","options":{"a":"int","b":"str","c":"None Type","d":"bool"},"ans":"c"},

    {"q":"27)How to access 1st element of list 1=[10,20]?","options":{"a":"1[0]","b":"1[1]","c":"1[-1]","d":"1.first"},"ans":"a"},

    {"q":"28)Which operator is used for logical AND ?","options":{"a":"and","b":"&","c":"&&","d":"|"},"ans":"a"},

    {"q":"29)Output:x=5;print('Yes'ifx>0 else 'No')","options":{"a":"Yes","b":"No","c":"Error","d":"5"},"ans":"a"},

    {"q":"30)Output:\ni=0\nwhile i<3:\n print(i)\n i+=1","options":{"a":"0 1 2","b":"1 2 3","c":"0 1 2 3","d":"Error"},"ans":"a"},

    {"q":"31)Which returns a value?","options":{"a":"print()","b":"return","c":"pass","d":"input()"},"ans":"b"},

    {"q":"32)Abstraction means?","options":{"a":"Hiding implementation","b":"Overloading","c":"Inheritance","d":""},"ans":"a"},

    {"q":"33)Which is mutable string type?","options":{"a":"str","b":"list","c":"tuple","d":"int"},"ans":"b"},

    {"q":"34)Which keyword is used to inhert?","options":{"a":"inherits","b":"super","c":"classB(A)","d":"extends"},"ans":"c"},

    {"q":"35)Output of bool(\"\")?","options":{"a":"True","b":"False","c":"None","d":"Error"},"ans":"b"},

    {"q":"36)How to create tuple with single element ?","options":{"a":"(1)","b":"(1,)","c":"[1]","d":"{1}"},"ans":"b"},

    {"q":"37)Output of 2*3**2?","options":{"a":"36","b":"18","c":"12","d":"none"},"ans":"b"},

    {"q":"38)Which of these is not keyword?","options":{"a":"pass","b":"eval","c":"assert","d":"return"},"ans":"b"},

    {"q":"39)Which method converts string to lowercase?","options":{"a":"llower()","b":"up()","c":"capitalize()","d":"lowercase()"},"ans":"a"},

    {"q":"40)Which collection stores key-value pairs?","options":{"a":"list","b":"tuple","c":"dict","d":"set"},"ans":"c"},



]
for item in questions:
    score += ask_question(item["q"], item["options"], item["ans"])

print(f"\n🎉 {player_name}, your final score is: {score}/{len(questions)} 🎉")
# Out:
# Welcome to Python Quiz Competition
# Enter your name:sujal
#
# 1)Which of the following is a valid variable name?
# a. 1var
# b. var1
# c. var-1
# d. var 1
# Enter your choice (a/b/c/d): b
# ✅Correct Answer!
#
# 2)What is the output of:x=5;x+=3;print(x)
# a. 8
# b. 53
# c. 5
# d. Error
# Enter your choice (a/b/c/d): a
# ✅Correct Answer!
#
# 3)Which of the following is immutable?
# a. List
# b. Set
# c. Tuple
# d. Dictionary
# Enter your choice (a/b/c/d): c
# ✅Correct Answer!
#
# 4)Type of 3.14 in Python?
# a. int
# b. float
# c. complex
# d. double
# Enter your choice (a/b/c/d): b
# ✅Correct Answer!
#
# 5)Which of these is a dictionary?
# a. [1,2,3]
# b. (1,2,3)
# c. {'a':1}
# d. {1,2,3}
# Enter your choice (a/b/c/d): c
# ✅Correct Answer!
#
# 6)What is outpu of len({1,2,3,4})?
# a. 3
# b. 4
# c. Error
# d. 0
# Enter your choice (a/b/c/d): b
# ✅Correct Answer!
#
# 7)Output of 5**2?
# a. 10
# b. 25
# c. 7
# d. 52
# Enter your choice (a/b/c/d): b
# ✅Correct Answer!
#
# ...
